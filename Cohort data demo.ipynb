# %%
import nlsy

NLSY_db = nlsy.NLSY_database("data.db")
(cohort_79, cohort_97) = NLSY_db.cohorts

# The Cohort.data() method returns a pandas dataframe, e.g.:
cohort_79.data().head()
# Out:
#    case_id  sample_id  sex  race  year  adjusted_income  age  curr_pregnant  \
# 0        1          5    2     3  1979            17370   20            NaN
# 1        1          5    2     3  1980               -5   -5            NaN
# 2        1          5    2     3  1981            14722   22            NaN
# 3        1          5    2     3  1982               -5   -5           -5.0
# 4        1          5    2     3  1983               -5   -5           -5.0
#
#    work_kind_limited  work_amount_limited    ...      weeks_worked_last_year  \
# 0                  0                    0    ...                          52
# 1                 -5                   -5    ...                          -5
# 2                  0                    0    ...                          52
# 3                 -5                   -5    ...                          -5
# 4                 -5                   -5    ...                          -5
#
# ...

# %%
# And similarly for the 97 cohort:
cohort_97.data().head()
# Out:
#    case_id  sample_id  sex  race  year  adjusted_income  age  curr_pregnant  \
# 0        1          1    2     3  1997               -4   15             -4
# 1        1          1    2     3  1998              741   17             -4
# 2        1          1    2     3  1999               -4   18             -4
# 3        1          1    2     3  2000            11874   19             -4
# 4        1          1    2     3  2001            10087   20             -4
#
#    work_kind_limited  work_amount_limited    ...      weeks_worked_last_year  \
# 0                NaN                  NaN    ...                          26
# 1                NaN                  NaN    ...                          52
# 2                NaN                  NaN    ...                          52
# 3                NaN                  NaN    ...                          53
# 4                NaN                  NaN    ...                          52
#
# ...

# %%
# If you'd like to export the data to CSVs...

cohort_79.data().to_csv("shocks_79.csv")

cohort_97.data().to_csv("shocks_97.csv")

print("Exported to CSVs")
# Out:
# Exported to CSVs
